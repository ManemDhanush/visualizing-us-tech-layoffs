# %%
import pandas as pd

# %%
data = pd.read_csv('final_data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0      company     state   location  Laid_Off Date_layoffs  \
# 0           0        Clinc  Michigan  Ann Arbor      40.0   2020-04-09
# 1           2  SecureWorks   Georgia    Atlanta     300.0   2023-08-14
# 2           3     Calendly   Georgia    Atlanta      60.0   2023-07-26
# 3           4  SecureWorks   Georgia    Atlanta     212.0   2023-02-07
# 4           5    Salesloft   Georgia    Atlanta     100.0   2023-02-07
#
#    Percentage  Company_Size_before_Layoffs  Company_Size_after_layoffs  \
# 0        32.0                        125.0                        85.0
# 1        15.0                       2000.0                      1700.0
# 2        10.0                        600.0                       540.0
# 3         9.0                       2356.0                      2144.0
# 4        10.0                       1000.0                       900.0
#
#    Industry     Stage Money_Raised_in_$_mil  Year       lat       lng
# ...

# %%
df = data.groupby(['state']).sum()

# %%
df.sort_values(by=['state'])
# Out:
#                 Unnamed: 0                                            company  \
# state
# Arizona               2938            EdgioBishop FoxGoDaddyEdgioCarvanaEdgio
# California          392808  ZumeWeee!BitwiseNS8Beyond MeatInvestCloudVideo...
# Colorado              3139  DutchieJumpcloudStediStreamTIFINOutsideFlytede...
# Connecticut           3198                         Sema4TomoKayak / OpenTable
# Delaware               191                                           Lokalise
# Florida               2416  FreightosSpringbigPicsartMagic LeapCitrixDeepw...
# Georgia                865  SecureWorksCalendlySecureWorksSalesloftGreenli...
# Idaho                   77                                       MicronMicron
# Illinois              3315  AtlasThoughtworksProject44ClearcoverThoughtwor...
# Indiana                195                                              Woven
# Kansas                 393                                           C2FOC2FO
# ...

# %%
df.to_csv('count.csv')
